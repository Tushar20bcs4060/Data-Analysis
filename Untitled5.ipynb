# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import nltk
import re
from nltk.corpus import stopwords
import string

data = pd.read_csv("C:/Users/Tushar Mani/OneDrive/Desktop/Minor Project/filename.csv")
data.head()
# Out:
#                     id      conversation_id               created_at  \
# 0  1510384725248122886  1510384725248122886  2022-04-02 22:32:34 UTC
# 1  1510384724820340738  1510276407640920065  2022-04-02 22:32:34 UTC
# 2  1510384722702401536  1510344575591895046  2022-04-02 22:32:34 UTC
# 3  1510384722639163397  1510374385894440969  2022-04-02 22:32:34 UTC
# 4  1510384722089754636  1510384722089754636  2022-04-02 22:32:33 UTC
#
#          date      time  timezone              user_id        username  \
# 0  2022-04-02  22:32:34         0            108327959  briansandholdt
# 1  2022-04-02  22:32:34         0   824673488896135168      7blacklabs
# 2  2022-04-02  22:32:34         0            112040522    useruaeruser
# 3  2022-04-02  22:32:34         0  1316924503616704513    mrgeorgegrey
# 4  2022-04-02  22:32:33         0           1362931315      drusillarn
#
#                                    name place  ... geo source user_rt_id  \
# ...

# %%
df_1 = pd.DataFrame(data['tweet'], columns=['tweet'])

# %%
df_1.shape
# Out:
# (10002, 1)

# %%
X_train = df_1.iloc[0:5000,:]
X_test = df_1.iloc[50001:,:]

# %%
print(data.columns)
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'language', 'mentions',
#        'urls', 'photos', 'replies_count', 'retweets_count', 'likes_count',
#        'hashtags', 'cashtags', 'link', 'retweet', 'quote_url', 'video',
#        'thumbnail', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
data = data[["username", "tweet", "language"]]

# %%
data.isnull().sum()
# Out:
# username    0
# tweet       0
# language    0
# dtype: int64

# %%
data["language"].value_counts()
# Out:
# en     8621
# pt      334
# und     281
# it      279
# in      114
# ru       97
# es       50
# ca       32
# fr       32
# ja       30
# pl       15
# fi       14
# de       12
# tr       12
# ar       12
# uk       10
# cs        8
# ro        7
# tl        5
# nl        4
# et        4
# no        4
# hi        4
# zh        4
# da        3
# sv        3
# el        2
# th        2
# sr        1
# ta        1
# ur        1
# ht        1
# lv        1
# is        1
# ps        1
# Name: language, dtype: int64

# %%
nltk.download('stopwords')
stemmer = nltk.SnowballStemmer("english")
stopword=set(stopwords.words('english'))

def clean(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split(' ') if word not in stopword]
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text=" ".join(text)
    return text
data["tweet"] = data["tweet"].apply(clean)
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Tushar
# [nltk_data]     Mani\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
text = " ".join(i for i in data.tweet)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.figure( figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
nltk.download('vader_lexicon')
sentiments = SentimentIntensityAnalyzer()
data["Positive"] = [sentiments.polarity_scores(i)["pos"] for i in data["tweet"]]
data["Negative"] = [sentiments.polarity_scores(i)["neg"] for i in data["tweet"]]
data["Neutral"] = [sentiments.polarity_scores(i)["neu"] for i in data["tweet"]]
data = data[["tweet", "Positive", "Negative", "Neutral"]]
data.head()
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\Tushar
# [nltk_data]     Mani\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                                                tweet  Positive  Negative  \
# 0  interest interview russia posit world quit fri...     0.288     0.231
# 1  rwtrollpatrol jimjordan 🤣🤣🤣🤣 one tri treason o...     0.000     0.161
# 2  mfarussia rusembusa russianembassi rusembindia...     0.192     0.135
# 3  stephenpoxon  lot peopl feel proxi war us russ...     0.131     0.244
# 4  “special oper ukraine”  better name “war” pref...     0.178     0.270
#
#    Neutral
# 0    0.481
# 1    0.839
# 2    0.673
# 3    0.625
# 4    0.552

# %%
positive =' '.join([i for i in data['tweet'][data['Positive'] > data["Negative"]]])
stopwords = set(STOPWORDS)
#wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(positive)
wordcloud = WordCloud(background_color = 'white', width = 1000, height = 1000).generate(positive)
plt.figure( figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

plt.title("The Positive Words", fontsize = 22)
plt.show()

# %%
negative =' '.join([i for i in data['tweet'][data['Negative'] > data["Positive"]]])
stopwords = set(STOPWORDS)
#wordcloud = WordCloud(stopwords=stopwords, background_color="black").generate(negative)
wordcloud = WordCloud(background_color = 'Black', width = 1000, height = 1000).generate(negative)
plt.figure( figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("The Negative Words", fontsize = 22)
plt.show()

# %%
data.head()
# Out:
#                                                tweet  Positive  Negative  \
# 0  interest interview russia posit world quit fri...     0.288     0.231
# 1  rwtrollpatrol jimjordan 🤣🤣🤣🤣 one tri treason o...     0.000     0.161
# 2  mfarussia rusembusa russianembassi rusembindia...     0.192     0.135
# 3  stephenpoxon  lot peopl feel proxi war us russ...     0.131     0.244
# 4  “special oper ukraine”  better name “war” pref...     0.178     0.270
#
#    Neutral
# 0    0.481
# 1    0.839
# 2    0.673
# 3    0.625
# 4    0.552

# %%
data.isnull().any()
# Out:
# tweet       False
# Positive    False
# Negative    False
# Neutral     False
# dtype: bool

# %%
length_train = data['tweet'].str.len().plot.hist(color = 'pink', figsize = (6, 4))

# %%
data[data['Positive'] >data['Negative']].head(10)
# Out:
#                                                 tweet  Positive  Negative  \
# 0   interest interview russia posit world quit fri...     0.288     0.231
# 2   mfarussia rusembusa russianembassi rusembindia...     0.192     0.135
# 10  cerbnord russia  richest countri world  peopl ...     0.299     0.000
# 11  anasalhajji   russia need western technolog pr...     0.149     0.000
# 12  report site russian asset compani still trade ...     0.263     0.000
# 13        friend whos expert russia mind give call🤭       0.348     0.000
# 15  gromepow doombergt honest turkey think big dea...     0.167     0.084
# 21  park deck  level car plane week ask russia spe...     0.231     0.000
# 22  myroslavapetsa  putin also tell citizen west w...     0.384     0.068
# 23    russia broad retreat kyiv seek regroup batter       0.231     0.000
#
#     Neutral  len
# 0     0.481   53
# 2     0.673  214
# 10    0.701  175
# 11    0.851  169
# 12    0.737   55
# 13    0.652   44
# 15    0.749  197
# ...

# %%
data[data['Negative'] >data['Positive']].head(10)
# Out:
#                                                 tweet  Positive  Negative  \
# 1   rwtrollpatrol jimjordan 🤣🤣🤣🤣 one tri treason o...     0.000     0.161
# 3   stephenpoxon  lot peopl feel proxi war us russ...     0.131     0.244
# 4   “special oper ukraine”  better name “war” pref...     0.178     0.270
# 6   dmytrokuleba abaerbock come ukrain it time str...     0.000     0.216
# 8   marcelvandenb liar warmong show pic pf atroc u...     0.132     0.447
# 9   kaminskimk 🤬🤬🤬🤬🤬🤬🤬🤬🤬🤬russian proud cultur  rus...     0.138     0.192
# 16  piersmorgan shouldn't anyth abouta bad war it ...     0.114     0.205
# 19  russianembassi mfarussia rusembukrain rusembus...     0.069     0.110
# 26  dmytrokuleba come ukrain it time strike insid ...     0.000     0.227
# 28  militaryhazard   donba virtual stand donba cri...     0.000     0.310
#
#     Neutral  len
# 1     0.839  180
# 3     0.625  141
# 4     0.552   80
# 6     0.784  121
# 8     0.421  156
# 9     0.670  133
# 16    0.681  130
# ...

# %%
data[data['Neutral'] >data['Positive']].head(10)
data[data['Neutral']>data['Negative']].head(10)
# Out:
#                                                 tweet  Positive  Negative  \
# 0   interest interview russia posit world quit fri...     0.288     0.231
# 1   rwtrollpatrol jimjordan 🤣🤣🤣🤣 one tri treason o...     0.000     0.161
# 2   mfarussia rusembusa russianembassi rusembindia...     0.192     0.135
# 3   stephenpoxon  lot peopl feel proxi war us russ...     0.131     0.244
# 4   “special oper ukraine”  better name “war” pref...     0.178     0.270
# 5   ukrain smash russia give everyth need drive an...     0.000     0.000
# 6   dmytrokuleba abaerbock come ukrain it time str...     0.000     0.216
# 7   apesar das sançõ receita de exportação de ener...     0.000     0.000
# 9   kaminskimk 🤬🤬🤬🤬🤬🤬🤬🤬🤬🤬russian proud cultur  rus...     0.138     0.192
# 10  cerbnord russia  richest countri world  peopl ...     0.299     0.000
#
#     Neutral  len
# 0     0.481   53
# 1     0.839  180
# 2     0.673  214
# 3     0.625  141
# 4     0.552   80
# 5     1.000   55
# 6     0.784  121
# ...

# %%
length_train = data['tweet'].str.len().plot.hist(color = 'pink', figsize = (6, 4))

# %%
data['Positive'].value_counts().plot.bar(color = 'blue', figsize = (100, 80))
# Out:
# <AxesSubplot:>

# %%
data['len'] = data['tweet'].str.len()

# %%
data.groupby('len').mean()['Positive'].plot.hist(color = 'grey', figsize = (6, 4),)
plt.title('variation of length')
plt.xlabel('Length')
plt.show()
